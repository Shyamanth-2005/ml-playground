# %%
import pandas as pd

# %%
df = pd.read_json("data/recipe.json")
df
# Out:
#           id      cuisine                                        ingredients
# 0      10259        greek  [romaine lettuce, black olives, grape tomatoes...
# 1      25693  southern_us  [plain flour, ground pepper, salt, tomatoes, g...
# 2      20130     filipino  [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3      22213       indian                [water, vegetable oil, wheat, salt]
# 4      13162       indian  [black pepper, shallots, cornflour, cayenne pe...
# ...      ...          ...                                                ...
# 39769  29109        irish  [light brown sugar, granulated sugar, butter, ...
# 39770  11462      italian  [KRAFT Zesty Italian Dressing, purple onion, b...
# 39771   2238        irish  [eggs, citrus fruit, raisins, sourdough starte...
# 39772  41882      chinese  [boneless chicken skinless thigh, minced garli...
# 39773   2362      mexican  [green chile, jalapeno chilies, onions, ground...
#
# [39774 rows x 3 columns]

# %%
# we can load json from url also 
df = pd.read_csv("https://api.exchangerate-api.com/v4/latest/USD")
df
# Out:
# Empty DataFrame
# ...

# %% [markdown]
# ## working with SQL

# %%
# a software is required called xammpp
# and if you need to import data from database(mysql) to python we need mysql.connector
# !pip install mysql.connector
# Out:
# ...
#      ---------------------------------------- 0.0/11.9 MB ? eta -:--:--
#       --------------------------------------- 0.3/11.9 MB ? eta -:--:--
#      ------ --------------------------------- 1.8/11.9 MB 8.4 MB/s eta 0:00:02
#      ----------------- ---------------------- 5.2/11.9 MB 11.4 MB/s eta 0:00:01
#      ----------------------------- ---------- 8.7/11.9 MB 13.1 MB/s eta 0:00:01
#      --------------------------------------  11.8/11.9 MB 13.9 MB/s eta 0:00:01
#      ---------------------------------------- 11.9/11.9 MB 13.5 MB/s  0:00:01
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for mysql.connector: filename=mysql_connector-2.2.9-cp312-cp312-win_amd64.whl size=248038 sha256=7fdc5f382583c510ff5dd038f691c889165c1e7f9885f0c0becb45584b458130
#   Stored in directory: c:\users\shyam\appdata\local\pip\cache\wheels\03\17\fa\d7604c72dd3dd6d3eb3d249abf36cc532c9a9b4354b8f1bc4f
# ...

# %%
import mysql.connector

# %%
# we have to create connection through python
conn = mysql.connector.connect(host="localhost",user="root",password="",database="world")
#mysql.connector.connect(host=)

# %%
# takes a query and connection as parameters
import pandas as pd
pd.read_sql_query("SELECT * FROM city WHERE CountryCode LIKE 'IND' ",conn)
# Out:
# C:\Users\Shyam\AppData\Local\Temp\ipykernel_19768\517165478.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("SELECT * FROM city WHERE CountryCode LIKE 'IND' ",conn)
#        ID                Name CountryCode        District  Population
# 0    1024     Mumbai (Bombay)         IND     Maharashtra    10500000
# 1    1025               Delhi         IND           Delhi     7206704
# 2    1026  Calcutta [Kolkata]         IND    West Bengali     4399819
# 3    1027    Chennai (Madras)         IND      Tamil Nadu     3841396
# 4    1028           Hyderabad         IND  Andhra Pradesh     2964638
# ..    ...                 ...         ...             ...         ...
# 336  1360        Ambala Sadar         IND         Haryana       90712
# 337  1361          Baidyabati         IND    West Bengali       90601
# ...

# %%
pd.read_sql_query("SELECT * FROM country WHERE  LifeExpectancy > 60",conn)
# Out:
# C:\Users\Shyam\AppData\Local\Temp\ipykernel_19768\3802441703.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("SELECT * FROM country WHERE  LifeExpectancy > 60",conn)
#     Code                  Name      Continent           Region  SurfaceArea  \
# 0    ABW                 Aruba  North America        Caribbean        193.0
# 1    AIA              Anguilla  North America        Caribbean         96.0
# 2    ALB               Albania         Europe  Southern Europe      28748.0
# 3    AND               Andorra         Europe  Southern Europe        468.0
# 4    ANT  Netherlands Antilles  North America        Caribbean        800.0
# ..   ...                   ...            ...              ...          ...
# 162  VIR  Virgin Islands, U.S.  North America        Caribbean        347.0
# ...

# %%
df = pd.read_sql_query("SELECT * FROM countrylanguage",conn)
df
# Out:
# C:\Users\Shyam\AppData\Local\Temp\ipykernel_19768\1533879884.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query("SELECT * FROM countrylanguage",conn)
#     CountryCode    Language IsOfficial  Percentage
# 0           ABW       Dutch          T         5.3
# 1           ABW     English          F         9.5
# 2           ABW  Papiamento          F        76.7
# 3           ABW     Spanish          F         7.4
# 4           AFG     Balochi          F         0.9
# ..          ...         ...        ...         ...
# 979         ZMB      Tongan          F        11.0
# 980         ZWE     English          T         2.2
# 981         ZWE     Ndebele          F        16.2
# 982         ZWE      Nyanja          F         2.2
# 983         ZWE       Shona          F        72.1
#
# [984 rows x 4 columns]
