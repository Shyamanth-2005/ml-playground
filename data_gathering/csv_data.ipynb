# %%
import pandas as pd

# %%
# %pwd
# Out:
# 'c:\\Users\\Shyam\\Desktop\\ml-playground\\data_gathering'

# %%
df  = pd.read_csv("data/chocolate_sales.csv")
df
# Out:
#           Sales Person    Country              Product        Date  \
# 0       Jehu Rudeforth         UK      Mint Chip Choco  04/01/2022
# 1          Van Tuxwell      India        85% Dark Bars  01/08/2022
# 2         Gigi Bohling      India  Peanut Butter Cubes  07/07/2022
# 3         Jan Morforth  Australia  Peanut Butter Cubes  27/04/2022
# 4       Jehu Rudeforth         UK  Peanut Butter Cubes  24/02/2022
# ...                ...        ...                  ...         ...
# 3277  Karlen McCaffrey  Australia  Spicy Special Slims  17/05/2024
# 3278    Jehu Rudeforth        USA           White Choc  07/06/2024
# 3279      Ches Bonnell     Canada  Organic Choco Syrup  26/07/2024
# 3280    Dotty Strutley      India              Eclairs  28/07/2024
# 3281  Karlen McCaffrey      India       70% Dark Bites  23/05/2024
#
#           Amount  Boxes Shipped
# 0      $5,320.00            180
# 1      $7,896.00             94
# 2      $4,501.00             91
# ...

# %%
# opening the csv file through url 

import requests
from io import StringIO


url = "https://raw.githubusercontent.com/cs109/2014_data/master/countries.csv"
headers = {"User-Agent":"Mozilla/5.0 (Machintosh; Intel Mac OS X 10:14; rv:66.0) Gecko/20100101 Firefox/66.0"}
req = requests.get(url,headers=headers)
data = StringIO(req.text)

df = pd.read_csv(data)

df.to_csv("countries.csv")

# %% [markdown]
# ## sep parameter in the read_csv()

# %%
# if you want to read .tsv files
df  = pd.read_csv("data/test_Arabic_tweets_negative_20190413.tsv",sep="/t") 
# df
# if you don't have names for the columns then we can pass list column names to the names parameter to reflect on the data
df = pd.read_csv("data/test_Arabic_tweets_negative_20190413.tsv",sep="/t",names=['negative-comments'])
df
# Out:
# C:\Users\Shyam\AppData\Local\Temp\ipykernel_33084\2745670572.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df  = pd.read_csv("data/test_Arabic_tweets_negative_20190413.tsv",sep="/t")
# C:\Users\Shyam\AppData\Local\Temp\ipykernel_33084\2745670572.py:5: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv("data/test_Arabic_tweets_negative_20190413.tsv",sep="/t",names=['negative-comments'])
#                                       negative-comments
# 0            neg\tحتى الايتونز خربتوه مو صاحين انتو؟؟ 😭
# 1     neg\tواحد تبع النظام السوري يقول أن المخابرات ...
# ...

# %% [markdown]
# ## 1. index_col parameter

# %%
df = pd.read_csv("data/countries.csv",index_col="Country")
df = df.drop("Unnamed: 0",axis=1)
df
# Out:
#                   Region
# Country
# Algeria           AFRICA
# Angola            AFRICA
# Benin             AFRICA
# Botswana          AFRICA
# Burkina           AFRICA
# ...                  ...
# Paraguay   SOUTH AMERICA
# Peru       SOUTH AMERICA
# Suriname   SOUTH AMERICA
# Uruguay    SOUTH AMERICA
# Venezuela  SOUTH AMERICA
#
# [194 rows x 1 columns]

# %% [markdown]
# ## 2. Header parameter

# %%
# if by mistake the data or the csv file has the first data row as the column names then
# what to do ?

df = pd.read_csv("data/chocolate_sales.csv",header=0) # i can change the header row to any row no
df
# Out:
#           Sales Person    Country              Product        Date  \
# 0       Jehu Rudeforth         UK      Mint Chip Choco  04/01/2022
# 1          Van Tuxwell      India        85% Dark Bars  01/08/2022
# 2         Gigi Bohling      India  Peanut Butter Cubes  07/07/2022
# 3         Jan Morforth  Australia  Peanut Butter Cubes  27/04/2022
# 4       Jehu Rudeforth         UK  Peanut Butter Cubes  24/02/2022
# ...                ...        ...                  ...         ...
# 3277  Karlen McCaffrey  Australia  Spicy Special Slims  17/05/2024
# 3278    Jehu Rudeforth        USA           White Choc  07/06/2024
# 3279      Ches Bonnell     Canada  Organic Choco Syrup  26/07/2024
# 3280    Dotty Strutley      India              Eclairs  28/07/2024
# 3281  Karlen McCaffrey      India       70% Dark Bites  23/05/2024
#
#           Amount  Boxes Shipped
# 0      $5,320.00            180
# 1      $7,896.00             94
# 2      $4,501.00             91
# ...

# %% [markdown]
# ## use_cols parameter

# %%
# used for only getting the wanted columns and nothing more
df = pd.read_csv("data/chocolate_sales.csv",usecols=["Sales Person","Country","Amount"])
df
# Out:
#           Sales Person    Country      Amount
# 0       Jehu Rudeforth         UK   $5,320.00
# 1          Van Tuxwell      India   $7,896.00
# 2         Gigi Bohling      India   $4,501.00
# 3         Jan Morforth  Australia  $12,726.00
# 4       Jehu Rudeforth         UK  $13,685.00
# ...                ...        ...         ...
# 3277  Karlen McCaffrey  Australia   $5,303.58
# 3278    Jehu Rudeforth        USA   $7,339.32
# 3279      Ches Bonnell     Canada     $616.09
# 3280    Dotty Strutley      India   $2,504.62
# 3281  Karlen McCaffrey      India   $5,915.87
#
# [3282 rows x 3 columns]

# %% [markdown]
# ## squeeze parameter

# %%
# if you only want one column then we can use sequence to converet a dataframe to series
# constraint use it only when you need one column

# df = pd.read_csv("data/chocolate_sales.csv",usecols=['Sales Person'],squeeze=True)
# the squeeze parameter is depreciated

ser = pd.read_csv("data/chocolate_sales.csv",usecols=["Sales Person"])["Sales Person"]
ser
# Out:
# 0         Jehu Rudeforth
# 1            Van Tuxwell
# 2           Gigi Bohling
# 3           Jan Morforth
# 4         Jehu Rudeforth
#               ...
# 3277    Karlen McCaffrey
# 3278      Jehu Rudeforth
# 3279        Ches Bonnell
# 3280      Dotty Strutley
# 3281    Karlen McCaffrey
# Name: Sales Person, Length: 3282, dtype: object

# %% [markdown]
# ## skiprows/nrows parameter

# %%
import pandas as pd
df = pd.read_csv("data/aug_test.csv",skiprows=lambda x: x%5 == 0) # removes all the rows with id numbers a multiple of 5
df
# Out:
#       32403   city_41  0.8270000000000001    Male  Has relevent experience  \
# 0      9858  city_103               0.920  Female  Has relevent experience
# 1     31806   city_21               0.624    Male   No relevent experience
# 2     27385   city_13               0.827    Male  Has relevent experience
# 3       217   city_23               0.899    Male   No relevent experience
# 4     21465   city_21               0.624     NaN  Has relevent experience
# ...     ...       ...                 ...     ...                      ...
# 1698  21339   city_21               0.624  Female   No relevent experience
# 1699    195  city_136               0.897    Male  Has relevent experience
# 1700  31762  city_100               0.887    Male   No relevent experience
# 1701   7873  city_102               0.804    Male  Has relevent experience
# 1702  12215  city_102               0.804    Male  Has relevent experience
#
# ...

# %%
# if you want to get only a certain number of rows or some specific number of rows then we use nrows
df = pd.read_csv("data/aug_test.csv",nrows=100)
df
# Out:
#     enrollee_id      city  city_development_index  gender  \
# 0         32403   city_41                   0.827    Male
# 1          9858  city_103                   0.920  Female
# 2         31806   city_21                   0.624    Male
# 3         27385   city_13                   0.827    Male
# 4         27724  city_103                   0.920    Male
# ..          ...       ...                     ...     ...
# 95         2934   city_75                   0.939    Male
# 96        12919  city_103                   0.920  Female
# 97         4386   city_21                   0.624    Male
# 98        22462   city_21                   0.624     NaN
# 99        13988  city_103                   0.920     NaN
#
#         relevent_experience enrolled_university education_level  \
# 0   Has relevent experience    Full time course        Graduate
# 1   Has relevent experience       no_enrollment        Graduate
# 2    No relevent experience       no_enrollment     High School
# ...

# %% [markdown]
# ## Encoding parameter

# %%
df = pd.read_csv("data/BX-Books.csv",encoding="latin-1") # utf-8 is the default but just in case the default does'nt work try different encoding
df
# Out:
# C:\Users\Shyam\AppData\Local\Temp\ipykernel_30072\2842933254.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("data/BX-Books.csv",encoding="latin-1") # utf-8 is the default but just in case the default does'nt work try different encoding
#               isbn                                         book_title  \
# 0        195153448                                Classical Mythology
# 1          2005018                                       Clara Callan
# 2         60973129                               Decision in Normandy
# 3        374157065  Flu: The Story of the Great Influenza Pandemic...
# 4        393045218                             The Mummies of Urumchi
# ...            ...                                                ...
# 271374   440400988                         There's a Bat in Bunk Five
# 271375   525447644                            From One to One Hundred
# ...

# %% [markdown]
# ## skip bad lines

# %%
df = pd.read_csv("data/BX-Books.csv",encoding="latin-1",on_bad_lines="skip") 
"""
deprectiated argument
error_bad_lines=False
"""
#if you want to skip the bad line then try the error_bad_lines=False
df
# Out:
# C:\Users\Shyam\AppData\Local\Temp\ipykernel_30072\1201071955.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("data/BX-Books.csv",encoding="latin-1",on_bad_lines="skip")
#               isbn                                         book_title  \
# 0        195153448                                Classical Mythology
# 1          2005018                                       Clara Callan
# 2         60973129                               Decision in Normandy
# 3        374157065  Flu: The Story of the Great Influenza Pandemic...
# 4        393045218                             The Mummies of Urumchi
# ...            ...                                                ...
# 271374   440400988                         There's a Bat in Bunk Five
# 271375   525447644                            From One to One Hundred
# 271376  006008667X  Lily Dale : The True Story of the Town that Ta...
# ...

# %% [markdown]
# ## dtypes parameter

# %%
df = pd.read_csv("data/aug_train.csv",dtype={"target":int}) # convert the datatype of any column you want just by mentioning the column name
df
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %% [markdown]
# ## handling dates

# %%
df = pd.read_csv("data/IPL Matches 2008-2020.csv",parse_dates=['date']) # if you want to convert the dates from object to proper date foramt
# if you have day / month / year separate but you want it as one column then we can use parse_dates = [["day_col","month_col","year_col"]]
# or parse_dates = {"foo":[1,3,4]}
df
# Out:
#           id        city       date player_of_match  \
# 0     335982   Bangalore 2008-04-18     BB McCullum
# 1     335983  Chandigarh 2008-04-19      MEK Hussey
# 2     335984       Delhi 2008-04-19     MF Maharoof
# 3     335985      Mumbai 2008-04-20      MV Boucher
# 4     335986     Kolkata 2008-04-20       DJ Hussey
# ..       ...         ...        ...             ...
# 811  1216547       Dubai 2020-09-28  AB de Villiers
# 812  1237177       Dubai 2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi 2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi 2020-11-08      MP Stoinis
# 815  1237181       Dubai 2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %% [markdown]
# ## Convertors

# %%
def rename(name):
  if name == "Royal Challengers Bangalore":
    return "RCB"
  return name

# %%
rename("Royal Challengers Bangalore")
# Out:
# 'RCB'

# %%
df = pd.read_csv("data/IPL Matches 2008-2020.csv",converters={'team1':rename})
# if you want to convert the data of some column we can just use the above parameter
df
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  2020-09-28  AB de Villiers
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %% [markdown]
# ## na_values parameter

# %%
df = pd.read_csv("data/aug_train.csv",na_values=["Male"]) # if you want to consider some of the categorical value empty in the columns then we can use the parameter
df
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920    NaN
# 1            29725   city_40                   0.776    NaN
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767    NaN
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878    NaN
# 19154        31398  city_103                   0.920    NaN
# 19155        24576  city_103                   0.920    NaN
# 19156         5756   city_65                   0.802    NaN
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %% [markdown]
# ## loading a huge dataset in chunks

# %%
dfs = pd.read_csv("data/aug_train.csv",chunksize=5000)

# %%
for chunks in dfs:
  print(chunks.shape)
# Out:
# (5000, 14)
# (5000, 14)
# (4158, 14)
